import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import io

from common import *

# %%
# load previous cell as text

tests = [
    Scenario('ULA', 3.5, ula3_5, "#004c6d"),
    Scenario('ULA', 20,  ula20 , "#6698b3"),
    Scenario('ULA', 100, ula100, '#beebff'),
    Scenario('UCA', 20,  uca20 , '#ed7d31')
]

uca_colors = [
    "#ff8629",
    "#bd4715",
    "#790000",
]

# String Copy/Paste interpretieren

for i, scenario in enumerate(tests):
    df = pd.read_csv(io.StringIO(scenario.data.strip()), sep="\t", header=None)
    df.index = [
        "Anzahl Peilungen Insgesamt",
        "Anzahl Peilungen mit Antwort",
        "MUSIC Peaks Separat - Mittelwert",
        "MUSIC Peaks Separat - Median",
        "MUSIC Peaks Separat - Standardabweichung",
        "MUSIC Peaks Separat - RMSE",
        "MUSIC Summe - Peak",
        "MUSIC Summe - Qualität",
        "PDOA01 - Mittelwert",
        "PDOA01 - Median",
        "PDOA01 - Standardabweichung",
        "PDOA01 - RMSE",
        "PDOA12 - Mittelwert",
        "PDOA12 - Median",
        "PDOA12 - Standardabweichung",
        "PDOA12 - RMSE",
        "PDOA02 - Mittelwert",
        "PDOA02 - Median",
        "PDOA02 - Standardabweichung",
        "PDOA02 - RMSE",
        "PDOA Mittel - Mittelwert",
        "PDOA Mittel - Median",
        "PDOA Mittel - Standardabweichung",
        "PDOA Mittel - RMSE"
    ]
    if scenario.type == 'ULA':
        df.columns = [-90, -60, -30, 0, 30, 60, 90]
    else:
        df.columns = [-150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180]
        # Kopiere 180° zu -180° für übergang in der Darstellung
        df.insert(0, -180, df.iloc[:, -1])
        

    tests[i].df = df

# Automatische, "Statische" Berechnungen
for scenario in tests:
    scenario.df.loc["Anteil Peilungen mit Antwort"] = scenario.df.loc["Anzahl Peilungen mit Antwort"] / scenario.df.loc["Anzahl Peilungen Insgesamt"]

# %%
# Anteil Peilungen mit Antwort

fig, ax = plt.subplots(figsize=FIG_SIZE)
ax.set_xlabel("α in °")
ax.set_ylabel("Antwortrate")

ax.set_ylim(0, 1)
make_x_angle(ax, df.columns)
ax.grid(True, which="major", axis="both")

for scenario in tests:
    X = scenario.df.columns
    ax.plot(X, scenario.df.loc["Anteil Peilungen mit Antwort"], label=scenario.name(), color=scenario.color)
    ax.scatter(X, scenario.df.loc["Anteil Peilungen mit Antwort"], color=scenario.color)

legend(ax)
fig.savefig("plots/Antwortrate.pdf", bbox_inches="tight")

# %%
# MUSIC Summe Peaks vs Alpha

fig, ax = plt.subplots(figsize=FIG_SIZE)
ax.set_xlabel("α in °")
ax.set_ylabel("Peak MUSIC-Summe in °")

make_x_angle(ax, df.columns)
make_y_angle(ax, df.columns)

ax.grid(True, which="major", axis="both")

ax.plot(df.columns, df.columns, color='#b0b0b0', linewidth=1)

for scenario in tests:
    X = scenario.df.columns
    scatterandwrapplot(ax, scenario.df.loc["MUSIC Summe - Peak"], label=scenario.name(), color=scenario.color)

legend(ax, loc="upper right")
fig.savefig("plots/MUSIC_Summe_Peaks_vs_Alpha.pdf", bbox_inches="tight")

# %%
# PDOA Mittelwert/Median vs Alpha
def pdoa(m: Literal['Mittelwert', 'Median', 'Standardabweichung', 'RMSE']):
    ucaRange01 = { -30, 0, 30, 60, 90, 120, 150}
    ucaRange12 = ({-180, -150, -120, -90}, {90, 120, 150, 180})
    ucaRange02 = {-150, -120, -90, -60, -30, 0, 30}

    # fig = plt.Figure(figsize=FIG_SIZE * 2)
    # gs = fig.add_gridspec(2, 4)
    # gs.update(wspace=0.4, hspace=0.3)
    # ax_tl = fig.add_subplot(gs[0, 0:2])
    # ax_tr = fig.add_subplot(gs[0, 2:4])
    # ax_bc = fig.add_subplot(gs[1, 1:3])
    # axs = [ax_tl, ax_tr, ax_bc]

    fig, axs = plt.subplots(nrows=3, figsize=FIG_SIZE * [1,3])
    fig.subplots_adjust(hspace=0.3)
    axs: list[Axes] = axs.flatten()

    angles180 = tests[-1].df.columns
    for ax in axs:
        ax.sharex(axs[0])
        ax.sharey(axs[0])
        ax.set_xlabel("α in °")
        make_x_angle(ax,angles180)
        if m in ('Mittelwert', 'Median'):
            make_y_angle(ax, angles180)
            ax.plot(angles180, angles180, color='#b0b0b0')
        ax.grid(True, which="major", axis="both")
        ax.set_ylabel(f"{m} PDOA in °")

    axs[0].set_title("PDOA ULA 0-1")
    axs[1].set_title("PDOA ULA 1-2")
    axs[2].set_title("PDOA UCA")

    plot = scatterandwrapplot
    for scenario in tests:
        X = scenario.df.columns
        if scenario.type == 'ULA':
            plot(axs[0], scenario.df.loc[f"PDOA01 - {m}"], label=scenario.name(), color=scenario.color)
            plot(axs[1], scenario.df.loc[f"PDOA12 - {m}"], label=scenario.name(), color=scenario.color)
            # plot(axs[2], scenario.df.loc[f"PDOA02 - {m}"], label=scenario.name(), color=scenario.color)
        else:
            plot(axs[2], scenario.df.loc[f"PDOA01 - {m}"].where(scenario.df.columns.isin(ucaRange01   ), np.nan), label="PDOA 01", color=uca_colors[0])
            plot(axs[2], scenario.df.loc[f"PDOA12 - {m}"].where(scenario.df.columns.isin(ucaRange12[0]), np.nan), label="PDOA 12", color=uca_colors[1])
            plot(axs[2], scenario.df.loc[f"PDOA12 - {m}"].where(scenario.df.columns.isin(ucaRange12[1]), np.nan),                  color=uca_colors[1])
            plot(axs[2], scenario.df.loc[f"PDOA02 - {m}"].where(scenario.df.columns.isin(ucaRange02   ), np.nan), label="PDOA 02", color=uca_colors[2])

    for ax in axs:
        legend(ax)
    return fig

pdoa('Mittelwert')        .savefig("plots/PDOA_Mittelwert_vs_Alpha.pdf", bbox_inches="tight")
# pdoa('Median')            .savefig("plots/PDOA_Median_vs_Alpha.pdf", bbox_inches="tight")
pdoa('Standardabweichung').savefig("plots/PDOA_Standardabweichung_vs_Alpha.pdf", bbox_inches="tight")
# pdoa('RMSE')              .savefig("plots/PDOA_RMSE_vs_Alpha.pdf", bbox_inches="tight")

# %%
ucaRange01 = { -30, 0, 30, 60, 90, 120, 150}
ucaRange12 = ({-180, -150, -120, -90}, {90, 120, 150, 180})
ucaRange02 = {-150, -120, -90, -60, -30, 0, 30}

fig, axs = plt.subplots(nrows=3, figsize=FIG_SIZE * [1,3])
fig.subplots_adjust(hspace=0.3)
axs: List[Axes] = axs.flatten()

angles180 = tests[-1].df.columns
for ax in axs:
    ax.sharex(axs[0])
    ax.sharey(axs[0])
    ax.set_xlabel("α in °")
    make_x_angle(ax,angles180)
    make_y_angle(ax, angles180)
    ax.plot(angles180, angles180, color='#b0b0b0')
    ax.grid(True, which="major", axis="both")
    ax.set_ylabel(f"PDOA Winkel in °")

axs[0].set_title("PDOA ULA 0-1")
axs[1].set_title("PDOA ULA 1-2")
axs[2].set_title("PDOA UCA")

zorder = 10
def plot(ax: Axes, mean, std, **kwargs):
    global zorder
    wrapfill(ax, mean, std, 1, 
        zorder=zorder, 
        alpha=.7,
        **kwargs
    )
    if kwargs.get('label') is not None:
        # kwargs['label'] = '±1σ'
        del kwargs['label']
    wrapplot(ax, mean, zorder=zorder+1, **kwargs)
    zorder += 2

for scenario in tests:
    X = scenario.df.columns
    if scenario.type == 'ULA':
        plot(axs[0], scenario.df.loc[f"PDOA01 - Mittelwert"], scenario.df.loc[f"PDOA01 - Standardabweichung"], label=scenario.name(), color=scenario.color)
        plot(axs[1], scenario.df.loc[f"PDOA12 - Mittelwert"], scenario.df.loc[f"PDOA12 - Standardabweichung"], label=scenario.name(), color=scenario.color)
    else:
        plot(axs[2], scenario.df.loc[f"PDOA01 - Mittelwert"].where(scenario.df.columns.isin(ucaRange01   ), np.nan), scenario.df.loc[f"PDOA01 - Standardabweichung"].where(scenario.df.columns.isin(ucaRange01   ), np.nan), label="PDOA 01", color=uca_colors[0])
        plot(axs[2], scenario.df.loc[f"PDOA12 - Mittelwert"].where(scenario.df.columns.isin(ucaRange12[0]), np.nan), scenario.df.loc[f"PDOA12 - Standardabweichung"].where(scenario.df.columns.isin(ucaRange12[0]), np.nan), label="PDOA 12", color=uca_colors[1])
        plot(axs[2], scenario.df.loc[f"PDOA12 - Mittelwert"].where(scenario.df.columns.isin(ucaRange12[1]), np.nan), scenario.df.loc[f"PDOA12 - Standardabweichung"].where(scenario.df.columns.isin(ucaRange12[1]), np.nan),                  color=uca_colors[1])
        plot(axs[2], scenario.df.loc[f"PDOA02 - Mittelwert"].where(scenario.df.columns.isin(ucaRange02   ), np.nan), scenario.df.loc[f"PDOA02 - Standardabweichung"].where(scenario.df.columns.isin(ucaRange02   ), np.nan), label="PDOA 02", color=uca_colors[2])

for ax in axs:
    legend(ax)

fig.savefig("plots/PDOA_Area_vs_Alpha.pdf", bbox_inches="tight")
